# %%
import torch
import os

# Default device
device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # Scaled YOLOv4

# %%
os.getcwd()
# Out:
# 'D:\\Rens\\Universiteit\\Master\\Jaar 1\\Q3\\Visual Analytics\\2AMV10'

# %%
os.chdir('D:\\rens\\Universiteit\\Master\\Jaar 1\\Q3\\Visual Analytics\\2AMV10\\models\\scaled_yolov4_150epochs_16batchsize')
os.getcwd()
# Out:
# 'D:\\rens\\Universiteit\\Master\\Jaar 1\\Q3\\Visual Analytics\\2AMV10\\models\\scaled_yolov4_150epochs_16batchsize'

# %%
MODEL_PATH = 'runs/exp2_yolov4-csp-results/best_yolov4-csp-results.pt'

# %%
model = torch.load(MODEL_PATH)['model']

# %%
model.model.zero_grad()

# %%
for key, value in model.model._modules.items():
    print(key)
    print(value)
# Out:
# 0
# Conv(
#   (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#   (act): MishCuda()
# )
# 1
# Conv(
#   (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#   (act): MishCuda()
# )
# 2
# Bottleneck(
#   (cv1): Conv(
#     (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): MishCuda()
#   )
#   (cv2): Conv(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): MishCuda()
#   )
# )
# 3
# Conv(
# ...

# %%
model.eval()
# Out:
# Model(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): MishCuda()
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): MishCuda()
#     )
#     (2): Bottleneck(
#       (cv1): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): MishCuda()
#       )
#       (cv2): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
for key, value in model.model._modules.items():
    print(key)
    print(value.type)
# Out:
# 0
# models.common.Conv
# 1
# models.common.Conv
# 2
# models.common.Bottleneck
# 3
# models.common.Conv
# 4
# models.common.BottleneckCSP
# 5
# models.common.Conv
# 6
# models.common.BottleneckCSP
# 7
# models.common.Conv
# 8
# models.common.BottleneckCSP
# 9
# models.common.Conv
# 10
# models.common.BottleneckCSP
# 11
# models.common.SPPCSP
# 12
# models.common.Conv
# 13
# torch.nn.modules.upsampling.Upsample
# 14
# models.common.Conv
# 15
# models.common.Concat
# 16
# models.common.BottleneckCSP2
# 17
# models.common.Conv
# 18
# torch.nn.modules.upsampling.Upsample
# 19
# models.common.Conv
# 20
# models.common.Concat
# 21
# models.common.BottleneckCSP2
# 22
# models.common.Conv
# 23
# models.common.Conv
# 24
# models.common.Concat
# 25
# models.common.BottleneckCSP2
# 26
# models.common.Conv
# 27
# models.common.Conv
# 28
# models.common.Concat
# 29
# models.common.BottleneckCSP2
# 30
# models.common.Conv
# 31
# models.yolo.Detect

# %% [markdown]
# # Pretrained AlexNet

# %%
from torchvision import models

# %%
# Define model
pretrained_model = models.alexnet(pretrained=True)

# %%
pretrained_model.features
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#   (1): ReLU(inplace=True)
#   (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (4): ReLU(inplace=True)
#   (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace=True)
#   (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU(inplace=True)
#   (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
pretrained_model.features._modules.items()
# Out:
# odict_items([('0', Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))), ('1', ReLU(inplace=True)), ('2', MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)), ('3', Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))), ('4', ReLU(inplace=True)), ('5', MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)), ('6', Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))), ('7', ReLU(inplace=True)), ('8', Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))), ('9', ReLU(inplace=True)), ('10', Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))), ('11', ReLU(inplace=True)), ('12', MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False))])

# %%
pretrained_model.features.zero_grad()

# %%
for index, layer in enumerate(pretrained_model.features):
    print(index)
    print(layer)
# Out:
# 0
# Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
# 1
# ReLU(inplace=True)
# 2
# MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# 3
# Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
# 4
# ReLU(inplace=True)
# 5
# MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# 6
# Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 7
# ReLU(inplace=True)
# 8
# Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 9
# ReLU(inplace=True)
# 10
# Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 11
# ReLU(inplace=True)
# 12
# MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)

# %% [markdown]
# # YoloV5 custom model from PyTorch hub

# %%
os.getcwd()
# Out:
# 'D:\\rens\\Universiteit\\Master\\Jaar 1\\Q3\\Visual Analytics\\2AMV10\\models\\scaled_yolov4_150epochs_16batchsize'

# %%
os.chdir('D:\\rens\\Universiteit\\Master\\Jaar 1\\Q3\\Visual Analytics\\2AMV10\\models\\yolov5l_100epochs_16batchsize')
os.getcwd()
# Out:
# 'D:\\rens\\Universiteit\\Master\\Jaar 1\\Q3\\Visual Analytics\\2AMV10\\models\\yolov5l_100epochs_16batchsize'

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path_or_model='runs/exp0-yolov5l-results/yolov5l_weights.pt')
# Out:
# Using cache found in C:\Users\Rens/.cache\torch\hub\ultralytics_yolov5_master
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-502aa43d9761> in <module>
# ----> 1 model = torch.hub.load('ultralytics/yolov5', 'custom', path_or_model='runs/exp0-yolov5l-results/yolov5l_weights.pt')
#
# d:\aanaconda3\envs\pytorch\lib\site-packages\torch\hub.py in load(github, model, *args, **kwargs)
#     347     sys.path.insert(0, repo_dir)
#     348
# --> 349     hub_module = import_module(MODULE_HUBCONF, repo_dir + '/' + MODULE_HUBCONF)
#     350
#     351     entry = _load_entry_from_hubconf(hub_module, model)
#
# d:\aanaconda3\envs\pytorch\lib\site-packages\torch\hub.py in import_module(name, path)
#      69         spec = importlib.util.spec_from_file_location(name, path)
#      70         module = importlib.util.module_from_spec(spec)
# ...
